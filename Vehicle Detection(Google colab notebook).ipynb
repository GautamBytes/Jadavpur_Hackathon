# %%
# !pip install -q git+https://github.com/THU-MIG/yolov10.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 69.0 MB/s eta 0:00:00
# ...

# %%
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt
# Out:
# --2024-07-03 11:04:34--  https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10n.pt [following]
# --2024-07-03 11:04:35--  https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10n.pt
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install opencv-python-headless

# %%
# !git clone https://github.com/Sourajit-Maity/juvdv2-vdvwc.git
# Out:
# Cloning into 'juvdv2-vdvwc'...
# remote: Enumerating objects: 5613, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 5613 (delta 0), reused 2 (delta 0), pack-reused 5610
# Receiving objects: 100% (5613/5613), 538.71 MiB | 15.98 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# Updating files: 100% (5626/5626), done.

# %%
# !yolo task=detect mode=train epochs=85 batch=64 plots=True \
model='/content/-q/yolov10n.pt' \
data='/content/juvdv2-vdvwc/data.yaml'
# Out:
# New https://pypi.org/project/ultralytics/8.2.48 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image
from ultralytics import YOLOv10

# %%
Image(filename='/content/runs/detect/train2/confusion_matrix.png', width=600)
Image(filename='/content/runs/detect/train2/results.png', width=600)
model_path = '/content/runs/detect/train2/weights/best.pt'
model = YOLOv10(model_path)
results = model(source='/content/juvdv2-vdvwc/val/images/Rainny/Night', conf=0.25,save=True)
# Out:
# image 1/50 /content/juvdv2-vdvwc/val/images/Rainny/Night/rainynight (651).jpg: 640x384 6 cars, 2 cycles, 110.6ms
# image 2/50 /content/juvdv2-vdvwc/val/images/Rainny/Night/rainynight (652).jpg: 640x384 5 cars, 1 cycle, 10.7ms
# image 3/50 /content/juvdv2-vdvwc/val/images/Rainny/Night/rainynight (653).jpg: 640x384 4 cars, 1 cycle, 10.0ms
# image 4/50 /content/juvdv2-vdvwc/val/images/Rainny/Night/rainynight (654).jpg: 640x384 4 cars, 1 cycle, 10.3ms
# image 5/50 /content/juvdv2-vdvwc/val/images/Rainny/Night/rainynight (655).jpg: 640x384 4 cars, 1 cycle, 9.8ms
# image 6/50 /content/juvdv2-vdvwc/val/images/Rainny/Night/rainynight (656).jpg: 640x384 4 cars, 1 cycle, 10.1ms
# image 7/50 /content/juvdv2-vdvwc/val/images/Rainny/Night/rainynight (657).jpg: 640x384 4 cars, 1 cycle, 12.0ms
# image 8/50 /content/juvdv2-vdvwc/val/images/Rainny/Night/rainynight (658).jpg: 640x384 4 cars, 1 cycle, 9.9ms
# ...

# %%
import glob
images = glob.glob('/content/runs/detect/predict/*.jpg')
for image in images:
  display(Image(filename = image,width=400))
